# %%
# =========================================================
# 1. MODEL COMPARISON
# =========================================================

import pandas as pd

comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest",
        "XGBoost"
    ],

    "Accuracy": [
        0.73,
        0.90,
        0.81
    ],

    "Macro Precision": [
        0.60,
        0.76,
        0.63
    ],

    "Macro Recall": [
        0.82,
        0.78,
        0.82
    ],

    "Macro F1": [
        0.60,
        0.77,
        0.65
    ]
})

display(comparison)
# Out:
#                  Model  Accuracy  Macro Precision  Macro Recall  Macro F1
# 0  Logistic Regression      0.73             0.60          0.82      0.60
# 1        Random Forest      0.90             0.76          0.78      0.77
# 2              XGBoost      0.81             0.63          0.82      0.65

# %%
# =========================================================
# 2. SAVE MODEL COMPARISON
# =========================================================

comparison.to_csv(
    "../results/model_comparison.csv",
    index=False
)

print(
    "Model comparison saved successfully!"
)
# Out:
# Model comparison saved successfully!
